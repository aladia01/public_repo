# %%
print('Hello')
# Out:
# StatementMeta(, 3531346e-1909-4004-a183-ee2f5d2e0270, 3, Finished, Available, Finished)
# Hello

# %%
from pyspark.sql.functions import col
# Out:
# StatementMeta(, 3531346e-1909-4004-a183-ee2f5d2e0270, 5, Finished, Available, Finished)

# %%
df = spark.sql("SELECT * FROM Lakehouse_AL_01.erp_data")
Cleandf = df.filter(col("category").isNotNull() )
df.count()
Cleandf.count()
# Out:
# StatementMeta(, 3531346e-1909-4004-a183-ee2f5d2e0270, 6, Finished, Available, Finished)
# 1897

# %%
df = spark.sql("SELECT * FROM Lakehouse_AL_01.erp_data")
Cleandf = df.where(col("price") > 0)
df.count()
Cleandf.count()
# Out:
# StatementMeta(, 3531346e-1909-4004-a183-ee2f5d2e0270, 7, Finished, Available, Finished)
# 1912
